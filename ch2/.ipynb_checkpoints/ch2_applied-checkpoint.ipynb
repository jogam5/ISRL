# %% [markdown]
# ## Exercises
# ### Applied

# %% [markdown]
# #### Question 8

# %% [markdown]
# ##### a). Read the data

# %%
import numpy as np
import pandas as pd

# %%
college_numpy = np.genfromtxt('/Users/gabriel/python/csc2515/winter2021/ISRL/ch2/College.csv', delimiter=',')
college_numpy.shape
# Out:
# (778, 19)

# %%
college = pd.read_csv('/Users/gabriel/python/csc2515/winter2021/ISRL/ch2/College.csv')

# %% [markdown]
# ##### b). Drop first column (name of universities) of the dataset

# %%
college = college.iloc[:, 0:] # [row_start:row_end, col_start, col_end] -> delete first column

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# **Pending:** How to change the left most column of numbers to the names of the universities?

# %% [markdown]
# ##### c.1  Produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ##### c.2A Produce a matrix of the first ten columns of the data

# %%
college.iloc[:,1:11] # From 0 to 9, 10 is not inclusive
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board
# 0            537      7440        3300
# 1           1227     12280        6450
# ...

# %% [markdown]
# ##### c.2B Produce a scatterplot matrix of the first ten columns

# %%
pd.plotting.scatter_matrix(college.iloc[:,:11], figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='Apps', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Accept', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Top10perc', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Top25perc', ylabel='Apps'>,
#         <AxesSubplot:xlabel='F.Undergrad', ylabel='Apps'>,
#         <AxesSubplot:xlabel='P.Undergrad', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Outstate', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Room.Board', ylabel='Apps'>],
#        [<AxesSubplot:xlabel='Apps', ylabel='Accept'>,
#         <AxesSubplot:xlabel='Accept', ylabel='Accept'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Accept'>,
#         <AxesSubplot:xlabel='Top10perc', ylabel='Accept'>,
#         <AxesSubplot:xlabel='Top25perc', ylabel='Accept'>,
#         <AxesSubplot:xlabel='F.Undergrad', ylabel='Accept'>,
#         <AxesSubplot:xlabel='P.Undergrad', ylabel='Accept'>,
# ...

# %% [markdown]
# ##### c.3 Produce a side-by-side boxplot of Outstate VS Private

# %%
college.boxplot(column=['Outstate'], by='Private')
# Out:
# <AxesSubplot:title={'center':'Outstate'}, xlabel='Private'>

# %% [markdown]
# A boxplot is a method to depict groups of numerical data using their quartiles. I has a **5 number summary**: minimum, Q1, median, Q3 and maximum. In this case, the **Outstate** variable describes the out of state tuition. The **Private** variable shows if the university is Public or Private. In the right hand side (YES column), the box plot suggests that for Private universities, the median tuition (or 50th) for an out-of-state student is around 11,000, whereas in Public universities, the median out-of-state is close to 7,000. This figures reflects that out-of-state students pay a considerable higher tuition in Private universities than in Public ones.

# %% [markdown]
# #### c.4 Create a qualitative variable called Elite

# %%
college['Elite'] = np.where(college['Top10perc'] > 50, True, False)
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college.boxplot(column=['Outstate'], by='Elite')
# Out:
# <AxesSubplot:title={'center':'Outstate'}, xlabel='Elite'>

# %% [markdown]
# #### c.5 Histogram

# %%
college.hist(column='Books')
# Out:
# array([[<AxesSubplot:title={'center':'Books'}>]], dtype=object)

# %%
college.hist(column='perc.alumni', bins=20, grid=False, legend=True, color='#FFCF56')
# Out:
# array([[<AxesSubplot:title={'center':'perc.alumni'}>]], dtype=object)

# %%
college.hist(column="Outstate", by="Elite")
# Out:
# array([<AxesSubplot:title={'center':'False'}>,
#        <AxesSubplot:title={'center':'True'}>], dtype=object)

# %% [markdown]
# -------------

# %% [markdown]
# #### Question 9: Auto data

# %% [markdown]
# Loading the data in pandas

# %%
auto = pd.read_csv('/Users/gabriel/python/isrl/ch2/Auto.csv')

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %% [markdown]
# ##### **9.a** Which of the predictors are quantitative and which are qualitative?

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# **Answer:** Qualitative -> name, Quantitative -> all the rest except **horsepower**.

# %% [markdown]
# **9.b** What is the range of each quantitative predictor?

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# **Answer:** From the table above the range can be calculated.

# %% [markdown]
# ##### **9.c** What is the mean and standard deviation of each quantity

# %% [markdown]
# **Answer:** Both quantities can be observed from the table above.

# %% [markdown]
# ##### **9.d** Remove the 10th through 85th observation and show the std, mean and range of the remainig data.

# %%
auto.drop(auto.index[10:85], inplace=True)

# %%
auto.info() # Rows were dropped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           322 non-null    float64
#  1   cylinders     322 non-null    int64
#  2   displacement  322 non-null    float64
#  3   horsepower    322 non-null    object
#  4   weight        322 non-null    int64
#  5   acceleration  322 non-null    float64
#  6   year          322 non-null    int64
#  7   origin        322 non-null    int64
#  8   name          322 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 25.2+ KB

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  322.000000  322.000000    322.000000   322.000000    322.000000
# mean    24.409317    5.378882    187.680124  2936.807453     15.700621
# std      7.913357    1.657398    100.120925   810.987533      2.706436
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.250000  2216.000000     14.000000
# 50%     23.900000    4.000000    145.500000  2797.500000     15.500000
# 75%     30.650000    6.000000    250.000000  3516.000000     17.275000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  322.000000  322.000000
# mean    77.130435    1.596273
# std      3.131849    0.815572
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ##### 9.e Use scatterplots to show the relationships between the predictors.

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(auto, figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='origin', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='year', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='origin', ylabel='cylinders'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='displacement'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='displacement'>,
# ...

# %% [markdown]
# Some of the findings:
# - The less weight the higher the mpg.
# - As the displacement increases, the weight also increases.
# - As the displacement increases, the mpg decreases.

# %% [markdown]
# ##### 9.f Do your plots suggest that any of the other variables might be useful in predicting **mpg**?

# %% [markdown]
# **Answer:** Displacement, Weight and Acceleration might be useful in predicting mpg, they graphs suggest a relationship between mpg and these variables.

# %%
auto.plot(kind='scatter', x='displacement', y='mpg', color='r')
auto.plot(kind='scatter', x='weight', y='mpg', color='g')
auto.plot(kind='scatter', x='acceleration', y='mpg', color='b')
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='mpg'>

# %% [markdown]
# As we can observe, both **weight** and **displacement** would be good datasets to fit a model to helps us predict **mpg**. On the other hand **acceleration** data might be too spread to yield an accurate forecast.

# %%
auto.boxplot(column=['mpg'], by='year')
# Out:
# <AxesSubplot:title={'center':'mpg'}, xlabel='year'>

# %% [markdown]
# The **year** predictor might allow use have a range for the **mpg**.

# %% [markdown]
# #### Question 10: Boston housing dataset.

# %%
boston = pd.read_excel('/Users/gabriel/python/isrl/ch2/boston.xls', sheet_name='boston.csv')

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    int64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    int64
#  9   TAX     506 non-null    int64
#  10  PT      506 non-null    float64
#  11  B       506 non-null    float64
#  12  LSTAT   506 non-null    float64
#  13  MV      506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ##### 10.a Describe the data

# %% [markdown]
# **Answer:** There are 506 rows and 14 columns. The data describes data related to Boston housing such as median value, average number of rooms per dwelling or index of accessibility to radial highways. It also includes less revealing data such as nitric oxides concentration (in parts per 10 million).
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per 10,000 USD
# - PTRATIO - pupil-teacher ratio by town
# - B - $1000(Bk - 0.63)^2$ where Bk is the proportion of blacks by town
# - LSTAT - percentage lower status of the population
# - MEDV - Median value of owner-occupied homes in USD 1000's

# %% [markdown]
# ##### 10.b Make some pairwise scatterplots of the predictors

# %%
pd.plotting.scatter_matrix(boston, figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='CRIM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='NOX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='AGE', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='DIS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RAD', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='TAX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='PT', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='B', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='MV', ylabel='CRIM'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='ZN'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='ZN'>,
# ...

# %% [markdown]
# Choosing one of the varibles to drill own on how it compares with respect to the rest. MV or **Median Value of home in thousand of USD**.
# 1. It seems that price decreases as lower status (LSTAT) also decreases.
# 2. Price is proportional to (RM) the average number of rooms per dwelling.

# %%
boston.plot(kind='scatter', x='LSTAT', y='MV', color='r')
boston.plot(kind='scatter', x='RM', y='MV', color='g')
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MV'>

# %% [markdown]
# ##### 10.c Are any of the predictors associated with per capita crime rate?

# %% [markdown]
# **Answer:** It seems that MV and LSTAT might be associated to CRIM.

# %%
boston.plot(kind='scatter', x='MV', y='CRIM', color='b')
boston.plot(kind='scatter', x='LSTAT', y='CRIM', color='y')
boston.plot(kind='scatter', x='AGE', y='CRIM', color='pink')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CRIM'>

# %% [markdown]
# Based on the graphs we might argue that CRIM increases as the values for AGE increment, whereas the lower the median value of a home the higher the per capita crime rate by town.

# %% [markdown]
# ##### 10.d Comment on some predictors

# %%
boston.hist(column='CRIM', bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>]], dtype=object)

# %%
boston.hist(column='TAX', bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'TAX'}>]], dtype=object)

# %%
boston.hist(column='PT', bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'PT'}>]], dtype=object)

# %% [markdown]
# **Answer:** The data shows that overall per capita crime rate is very low, in 350 samples it's zero. Regarding taxes, it stands out that there's a tax rate of almost 700,000 USD ocurring in more than 120 samples. The PT ratio lays between 14 and 20 in most of the instances but there's a PT just above 20 that accounts for almost 140 samples.

# %% [markdown]
# ##### 10.e How many of the suburbs in this data set bound the Charles river?

# %%
# Method # 1
y, _, _ = plt.hist(boston['CHAS'])

# %%
print(y)
# Out:
# [471.   0.   0.   0.   0.   0.   0.   0.   0.  35.]

# %%
# Method 2
boston['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %% [markdown]
# **Answer:** There are 35 towns that bound the river.

# %% [markdown]
# ##### 10.f What is the median Pupil-Teacher ratio (PT)?

# %%
boston['PT'].median()
# Out:
# 19.05000019

# %% [markdown]
# ##### 10.g

# %%
boston[['MV']].idxmin()
# Out:
# MV    398
# dtype: int64

# %% [markdown]
# The suburb with the lowest MV is in the **index 398** of the dataset. To confirm the finding:

# %%
boston.iloc[397:400]
# Out:
#           CRIM   ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 397   7.672020  0.0   18.1     0  0.693  5.747   98.900002  1.6334   24  666
# 398  38.351799  0.0   18.1     0  0.693  5.453  100.000000  1.4896   24  666
# 399   9.916550  0.0   18.1     0  0.693  5.852   77.800003  1.5004   24  666
#
#             PT           B      LSTAT   MV
# 397  20.200001  393.100006  19.920000  8.5
# 398  20.200001  396.899994  30.590000  5.0
# 399  20.200001  338.160004  29.969999  6.3

# %% [markdown]
# From the table above we observe the specific value of the other predictors for sample **398**.

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX          PT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674030
# ...

# %% [markdown]
# Sample **398** CRIM is above the 75th, the max value is almost 88; TAX is in the 75th with 666; PT is also in the 75th with 20.2. Since the **398** sample is at the extreme of MV, some predictors show a strong correlation such as the CRIM variable.

# %% [markdown]
# ##### 10.h

# %% [markdown]
# Suburbs with an average of more than seven and eight rooms per dwelling.

# %%
boston['RM'].describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %%
boston[ boston['RM'] > 7 ].count().RM
# Out:
# 64

# %%
boston[ boston['RM'] > 8 ].count().RM
# Out:
# 13

# %% [markdown]
# **Answer:** There are *64* and *13* suburbs with seven and eight rooms per dwelling respectively. The 13 suburbs with an average of more than 8 RM are above the 75th 6.62), they probably are in the bracket with higher median value (MV).

# %%
boston[ boston['RM'] > 8]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM        AGE     DIS  RAD  TAX  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.000000  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.900002  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.900000  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.300003  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.000000  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.500000  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.300003  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.400002  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.400000  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.900002  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.500000  2.2885    5  264
# ...

# %% [markdown]
# The table above shows that MV for all these suburbs is among the highest.
